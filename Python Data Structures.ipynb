# %% [markdown]
# # Intro to Python Data Structures and oop

# %% [markdown]
# ***We will cover classes, inheritance, method overriding, kwargs, and polymorphism.***
# ***Also datastructure***

# %%
def printass():
    print2()
def print2():
    print("Afnan")
if __name__=="__main__":  ###When you deal with the main file not an imported one  (imagine that you have 2 files and you just want to import one in your main program, just instead of main use the another name file)
    printass()
# Out:
# Afnan

# %%
###when your code break out just from kernal restart it , because the interpreter deal with your variables and build in function in one session so when you restart the kernal the python understand the functions like print function as a created one not build in function
### in python if you want to build the function without determine the functionality earlier you can do it by this way (if __name__=="__main__":) but generally you should first build the function then call it
###OOP
class person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

A = person("Ahmed", 25)

print(A.age)
print(A.name)
print("--------------------------------")


class Animal:
    def __init__(self, namevalue):
        self.namevalue = namevalue

    def sound(self):
        print("this is sound {}".format(self.namevalue))
    def isrunning(self):
        print("this is {}".format(self.namevalue))

cat = Animal("cat")
dog=Animal("dog")
cat.sound()
dog.isrunning()
# Out:
# 25
# Ahmed
# --------------------------------
# this is sound cat
# this is dog

# %%
#### if we do not have objects yet the python call a constructor like this 
### def__init__(self):
###   pass
###
class human:
    def __init__(self,fname="mohammed",lname="hassan",age=70):
        self.fname=fname
        self.lname=lname
        self.age=age
    def fullname(self):
        print("This is full name {} {} ".format(self.fname,self.lname))
    def fullinformation(self):
        print("this is the full information {} {} {}".format(self.fname,self.lname,self.age))
humana=human()
humana.fullname()
humanb=human("jere","haremza",47)
humanb.age=49
humanb.fullinformation()
### what's happened exactly :when you did not pass values throuh your object it will pass the initalization values you passed through the default constructor
###if you do pass value it will use it in methods
# Out:
# This is full name mohammed hassan
# this is the full information jere haremza 49

# %%
###encapsulation
class salary:
    def __init__(self,name,balance=500):
        self.name=name
        self.balance=balance
    def deposit(self):
        return self.balance+500
employee=salary("ahmed",500)
employee.deposit()
# Out:
# 1000

# %%
###When using kwargs you should pass values like Iname="afnan",salary=800 , the kwargs store the data in to dictionary
class people:
    def __init__(self,**kwargs):
        self.info=kwargs
    def setName(self,Iname):
        self.info['Iname']=Iname
    def getName(self):
        return self.info.get('name','noname')
    def setsalary(self,salary):
        self.info['salary']=salary
    def getsalary(self):
        return self.info.get('salary','nosalary')
Afnan=people(Iname='afnan',salary=500)
Afnan.getsalary()
Afnan.setsalary(1000)
print(Afnan.getsalary())
# Out:
# 1000

# %%
class Person:
    def __init__(self,**kwargs):
        self.infos = kwargs


    def  setName(self, lname):
        self.infos['lname'] = lname
    def getName(self ):
        return  self.infos.get('lname',"no name")

    def  setsalary(self, salary):
        self.infos['salary'] = salary
    def getsalary(self ):
        return  self.infos.get('salary',"no salary")

    def  setdept(self, dept):
        self.infos['dept'] = dept
    def getdept(self ):
        return  self.infos.get('dept',"no dept")

usama = Person(lname="Ahmed",salary=3000,dept="IT")
#usama = Person(lnames="Ahmed" )
print(usama.getName())

usama.setName('Wisam')

print(usama.getName())

print(usama.getsalary())
print(usama.getdept())

usama.setdept("Programming Python")

print(usama.getdept())
# Out:
# Ahmed
# Wisam
# 3000
# IT
# Programming Python

# %%
class Animal:
    def __init__(self, **kwargs):
        self.info = kwargs
    def setsound(self,sound):
        self.info['sound']='sound'
    def getsound(self):
        return self.info.get('sound')
class cat(Animal):
    def setsound(self):
       self.info['sound']='meaw'
c=cat(sound="cat")
c.setsound()
print(c.getsound())
# Out:
# meaw

# %%
class animal :
    def __init__(self,sound):
        self.sound=sound
    def sound(self):
        print("this is sound")
class cat(animal):
    def name(self):
        super().sound()
        print("meaw")
        
c=cat("meaw")
c.name()
# Out:
# this is sound
# meaw

# %% [markdown]
# ## Sequences: String, List, Tuple
# ****
# **indexing** - access any item in the sequence using its index.
# Indexing starts with 0 for the first element.

# %%
# string
x = 'frog'
print (x[3])

# list
x = ['pig', 'cow', 'horse']
print (x[1])
# Out:
# g
# cow

# %% [markdown]
# **slicing** - slice out substrings, sublists, subtuples using indexes.
# [start : end+1 : step]

# %%
x = 'computer'
print(x[1:4])
print(x[1:6:2])
print(x[3:])
print(x[:5])
print(x[-1])
print(x[-3:])
print(x[:-2])
# Out:
# omp
# opt
# puter
# compu
# r
# ter
# comput

# %% [markdown]
# **adding / concatenating** - combine 2 sequences of the same type by using +

# %%
# string
x = 'horse' + 'shoe'
print(x)

# list
y = ['pig', 'cow'] + ['horse']
print(y)
# Out:
# horseshoe
# ['pig', 'cow', 'horse']

# %% [markdown]
# **multiplying** - multiply a sequence using *

# %%
# string
x = 'bug' * 3
print(x)

# list
y = [8, 5] * 3
print(y)
# Out:
# bugbugbug
# [8, 5, 8, 5, 8, 5]

# %% [markdown]
# **checking membership** - test whether an item is or is not in a sequence.

# %%
# string
x = 'bug'
print('u' in x)

# list
y = ['pig', 'cow', 'horse']
print('cow' not in y)
# Out:
# True
# False

# %% [markdown]
# **iterating** - iterating through the items in a sequence

# %%
# item
x = [7, 8, 3]
for item in x:
    print(item)
    
# index & item
y = [7, 8, 3]
for index, item in enumerate(y):
    print(index, item)
# Out:
# 7
# 8
# 3
# 0 7
# 1 8
# 2 3

# %% [markdown]
# **number of items** - count the number of items in a sequence

# %%
# string
x = 'bug'
print(len(x))

# list
y = ['pig', 'cow', 'horse']
print(len(y))
# Out:
# 3
# 3

# %% [markdown]
# **minimum** - find the minimum item in a sequence lexicographically.
# Alpha or numeric types, but cannot mix types.

# %%
# string
x = 'bug'
print(min(x))

# list
y = ['pig', 'cow', 'horse']
print(min(y))
# Out:
# b
# cow

# %% [markdown]
# **maximum** - find the maximum item in a sequence lexicographically.
# Alpha or numeric types, but cannot mix types.

# %%
# string
x = 'bug'
print(max(x))

# list
y = ['pig', 'cow', 'horse']
print(max(y))
# Out:
# u
# pig

# %% [markdown]
# **sum** - find the sum of items in a sequence.
# Entire sequence must be numeric.

# %%
# string -> error
# x = [5, 7, 'bug']
# print(sum(x))    # generates an error

# list
y = [2, 5, 8, 12]
print(sum(y))
print(sum(y[-2:]))
# Out:
# 27
# 20

# %% [markdown]
# **sorting** - returns a new list of items in sorted order.
# Does not change the original list.

# %%
# string
x = 'bug'
print(sorted(x))

# list
y = ['pig', 'cow', 'horse']
print(sorted(y))
# Out:
# ['b', 'g', 'u']
# ['cow', 'horse', 'pig']

# %% [markdown]
# **count(item)** - returns count of an item

# %%
# string
x = 'hippo'
print(x.count('p'))

# list
y = ['pig', 'cow', 'horse', 'cow']
print(y.count('cow'))
# Out:
# 2
# 2

# %% [markdown]
# **index(item)** - returns the index of the first occurence of an item.

# %%
# string
x = 'hippo'
print(x.index('p'))

# list
y = ['pig', 'cow', 'horse', 'cow']
print(y.index('cow'))
# Out:
# 2
# 1

# %% [markdown]
# **unpacking** - unpack the n items of a sequence into n variables

# %%
x = ['pig', 'cow', 'horse']
a, b, c = x
print(a, b, c)
# Out:
# pig cow horse

# %% [markdown]
# ## Lists
# ****
# - General purpose
# - Most widely used data structure
# - Grow and shrink size as needed
# - Sequence type
# - Sortable
#
# **constructors** - creating a new list

# %%
x = list()
y = ['a', 25, 'dog', 8.43]
tuple1 = (10, 20)
z = list(tuple1)

# list comprehension
a = [m for m in range(8)]
print(a)
b = [i**2 for i in range(10) if i>4]
print(b)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]
# [25, 36, 49, 64, 81]

# %% [markdown]
# **delete** - delete a list or an item in a list

# %%
x = [5, 3, 8, 6]
del(x[1])
print(x)
del(x)    # list x no longer exists
# Out:
# [5, 8, 6]

# %% [markdown]
# **append** - append an item to a list

# %%
x = [5, 3, 8, 6]
x.append(7)
print(x)
# Out:
# [5, 3, 8, 6, 7]

# %% [markdown]
# **extend** - append a sequence to a list

# %%
x = [5, 3, 8, 6]
y = [12, 13]
x.extend(y)
print(x)
# Out:
# [5, 3, 8, 6, 12, 13]

# %% [markdown]
# **insert** - insert an item at a given index

# %%
x = [5, 3, 8, 6]
x.insert(1, 7)
print(x)
x.insert(1, ['a', 'm'])
print(x)
# Out:
# [5, 7, 3, 8, 6]
# [5, ['a', 'm'], 7, 3, 8, 6]

# %% [markdown]
# **pop** - pops last item off list and returns item

# %%
x = [5, 3, 8, 6]
x.pop()    # pop off the 6
print(x)
print(x.pop())
# Out:
# [5, 3, 8]
# 8

# %% [markdown]
# **remove** - remove first instance of an item

# %%
x = [5, 3, 8, 6, 3]
x.remove(3)
print(x)
# Out:
# [5, 8, 6, 3]

# %% [markdown]
# **reverse** - reverse the order of the list. It is an in-place sort, meaning it changes the original list.

# %%
x = [5, 3, 8, 6]
x.reverse()
print(x)
# Out:
# [6, 8, 3, 5]

# %% [markdown]
# **sort** - sort the list in place.
# Note:
# sorted(x) returns a new sorted list without changing the original list x.
# x.sort() puts the items of x in sorted order (sorts in place).

# %%
x = [5, 3, 8, 6]
x.sort()
print(x)
# Out:
# [3, 5, 6, 8]

# %% [markdown]
# ## Tuples
# ****
# - Immutable (can’t add/change)
# - Useful for fixed data
# - Faster than Lists
# - Sequence type
#
# **constructors** - creating new tuples.

# %%
x = ()
x = (1, 2, 3)
x = 1, 2, 3
x = 2,    # the comma tells Python it's a tuple
print(x, type(x))

list1 = [2, 4, 6]
x = tuple(list1)
print(x, type(x))
# Out:
# (2,) <class 'tuple'>
# (2, 4, 6) <class 'tuple'>

# %% [markdown]
# **tuples are immutable**, but member objects may be mutable.

# %%
x = (1, 2, 3)
# del(x[1])       # fails
# x[1] = 8        # fails
print(x)

y = ([1, 2], 3)   # a tuple where the first item is a list
del(y[0][1])      # delete the 2
print(y)          # the list within the tuple is mutable
# Out:
# (1, 2, 3)
# ([1], 3)

# %% [markdown]
# ## Sets
# ****
# - Store non-duplicate items
# - Very fast access vs Lists
# - Math Set ops (union, intersect)
# - Sets are Unordered
#
# **constructors** - creating new sets

# %%
x = {3, 5, 3, 5}
print(x)

y = set()
print(y)

list1 = [2, 3, 4]
z = set(list1)
print(z)
# Out:
# {3, 5}
# set()
# {2, 3, 4}

# %% [markdown]
# **set operations**

# %%
x = {3, 8, 5}
print(x)
x.add(7)
print(x)

x.remove(3)
print(x)

# get length of set x
print(len(x))

# check membership in x
print(5 in x)

# pop random item from set x
print(x.pop(), x)

# delete all items from set x
x.clear()
print(x)
# Out:
# {8, 3, 5}
# {8, 3, 5, 7}
# {8, 5, 7}
# 3
# True
# 8 {5, 7}
# set()

# %% [markdown]
# **Mathematical set operations**
# intersection (AND): set1 & set2
# union (OR): set1 | set1
# symmetric difference (XOR): set1 ^ set2
# difference (in set1 but not set2): set1 - set2
# subset (set2 contains set1): set1 <= set2
# superset (set1 contains set2): set1 >= set2

# %%
s1 = {1, 2, 3}
s2 = {3, 4, 5}
print(s1 & s2)
print(s1 | s2)
print(s1 ^ s2)
print(s1 - s2)
print(s1 <= s2)
print(s1 >= s2)
# Out:
# {3}
# {1, 2, 3, 4, 5}
# {1, 2, 4, 5}
# {1, 2}
# False
# False

# %% [markdown]
# ## Dictionaries (dict)
# ****
# - Key/Value pairs
# - Associative array, like Java HashMap
# - Dicts are Unordered

# %%
x = {'pork':25.3, 'beef':33.8, 'chicken':22.7}
print(x)
x = dict([('pork', 25.3),('beef', 33.8),('chicken', 22.7)])
print(x)
x = dict(pork=25.3, beef=33.8, chicken=22.7)
print(x)
# Out:
# {'pork': 25.3, 'beef': 33.8, 'chicken': 22.7}
# {'pork': 25.3, 'beef': 33.8, 'chicken': 22.7}
# {'pork': 25.3, 'beef': 33.8, 'chicken': 22.7}

# %% [markdown]
# **dict operations**

# %%
x['shrimp'] = 38.2    # add or update
print(x)

# delete an item
del(x['shrimp'])
print(x)

# get length of dict x
print(len(x))

# delete all items from dict x
x.clear()
print(x)

# delete dict x
del(x)
# Out:
# {'pork': 25.3, 'beef': 33.8, 'chicken': 22.7, 'shrimp': 38.2}
# {'pork': 25.3, 'beef': 33.8, 'chicken': 22.7}
# 3
# {}

# %% [markdown]
# **accessing keys and values in a dict**

# %%
y = {'pork':25.3, 'beef':33.8, 'chicken':22.7}
print(y.keys())
print(y.values())
print(y.items())      # key-value pairs

# check membership in y_keys (only looks in keys, not values)
print('beef' in y)

# check membership in y_values
print('clams' in y.values())
# Out:
# dict_keys(['pork', 'beef', 'chicken'])
# dict_values([25.3, 33.8, 22.7])
# dict_items([('pork', 25.3), ('beef', 33.8), ('chicken', 22.7)])
# True
# False

# %% [markdown]
# **iterating a dict - note, items are in random order**

# %%
for key in y:
    print(key, y[key])
    
for k, v in y.items():
    print(k, v)
# Out:
# pork 25.3
# beef 33.8
# chicken 22.7
# pork 25.3
# beef 33.8
# chicken 22.7
